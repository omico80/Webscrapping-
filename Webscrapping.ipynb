# %%
# Web Scrapping Assignment // Using the " Beautiful Soup" library 

# import the required library 
import os
import re
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Target URL to scap
url = "https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2"

# %%
#send request to download the file
response = requests.request("GET", url)

# %%
# parse the download data
data = BeautifulSoup(response.text,"html.parser")
print(data.prettify()[:10000])
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title data-rh="true">
#    A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code | by Amina Saeed | Medium
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1" data-rh="true" name="viewport"/>
#   <meta content="#000000" data-rh="true" name="theme-color"/>
#   <meta content="Medium" data-rh="true" name="twitter:app:name:iphone"/>
#   <meta content="828256236" data-rh="true" name="twitter:app:id:iphone"/>
#   <meta content="Medium" data-rh="true" property="al:ios:app_name"/>
#   <meta content="828256236" data-rh="true" property="al:ios:app_store_id"/>
#   <meta content="com.medium.reader" data-rh="true" property="al:android:package"/>
#   <meta content="542599432471018" data-rh="true" property="fb:app_id"/>
#   <meta content="Medium" data-rh="true" property="og:site_name"/>
#   <meta content="article" data-rh="true" property="og:type"/>
#   <meta content="2023-10-19T06:52:56.421Z" data-rh="true" property="article:published_time"/>
#   <meta content="A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code | by Amina Saeed | Medium" data-rh="true" name="title"/>
#   <meta content="A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code" data-rh="true" property="og:title"/>
#   <meta content="medium://p/f98d22fac8e2" data-rh="true" property="al:android:url"/>
#   <meta content="medium://p/f98d22fac8e2" data-rh="true" property="al:ios:url"/>
#   <meta content="Medium" data-rh="true" property="al:android:app_name"/>
#   <meta content="In the world of programming and data science, efficient management of software dependencies is crucial. Miniconda, a lightweight distribution of the popular Anaconda Python distribution, provides a…" data-rh="true" name="description"/>
#   <meta content="In the world of programming and data science, efficient management of software dependencies is crucial." data-rh="true" property="og:description"/>
#   <meta content="https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2" data-rh="true" property="og:url"/>
#   <meta content="https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2" data-rh="true" property="al:web:url"/>
#   <meta content="https://miro.medium.com/v2/da:true/resize:fit:1200/0*24B-GT-dWuxmF_vX" data-rh="true" property="og:image"/>
#   <meta content="https://medium.com/@aminasaeed223" data-rh="true" property="article:author"/>
#   <meta content="Amina Saeed" data-rh="true" name="author"/>
#   <meta content="index,follow,max-image-preview:large" data-rh="true" name="robots"/>
#   <meta content="unsafe-url" data-rh="true" name="referrer"/>
#   <meta content="A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code" data-rh="true" property="twitter:title"/>
#   <meta content="@Medium" data-rh="true" name="twitter:site"/>
#   <meta content="medium://p/f98d22fac8e2" data-rh="true" name="twitter:app:url:iphone"/>
#   <meta content="In the world of programming and data science, efficient management of software dependencies is crucial." data-rh="true" property="twitter:description"/>
#   <meta content="https://miro.medium.com/v2/da:true/resize:fit:1200/0*24B-GT-dWuxmF_vX" data-rh="true" name="twitter:image:src"/>
#   <meta content="summary_large_image" data-rh="true" name="twitter:card"/>
#   <meta content="Reading time" data-rh="true" name="twitter:label1"/>
#   <meta content="4 min read" data-rh="true" name="twitter:data1"/>
#   <meta content="2" data-rh="true" name="twitter:tile:template:testing"/>
#   <meta content="https://miro.medium.com/v2/da:true/resize:fit:1200/0*24B-GT-dWuxmF_vX" data-rh="true" name="twitter:tile:image"/>
#   <meta content="Person" data-rh="true" name="twitter:tile:info1:icon"/>
#   <meta content="Amina Saeed" data-rh="true" name="twitter:tile:info1:text"/>
#   <meta content="Calendar" data-rh="true" name="twitter:tile:info2:icon"/>
#   <meta content="Oct 19, 2023" data-rh="true" name="twitter:tile:info2:text"/>
#   <meta content="Read on Medium" data-rh="true" name="twitter:cta"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/1*m-R_BkNf1Qjr1YbyOIJY2w.png" rel="icon"/>
#   <link data-rh="true" href="/osd.xml" rel="search" title="Medium" type="application/opensearchdescription+xml"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:152:152/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:120:120/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:76:76/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:60:60/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link color="#171717" data-rh="true" href="https://cdn-static-1.medium.com/_/fp/icons/Medium-Avatar-500x500.svg" rel="mask-icon"/>
#   <link crossorigin="" data-rh="true" href="https://glyph.medium.com" rel="preconnect"/>
#   <link as="style" data-rh="true" href="https://glyph.medium.com/css/unbound.css" id="glyph_preload_link" rel="preload" type="text/css"/>
#   <link data-rh="true" href="https://glyph.medium.com/css/unbound.css" id="glyph_link" rel="stylesheet" type="text/css"/>
#   <link data-rh="true" href="https://medium.com/@aminasaeed223" rel="author"/>
#   <link data-rh="true" href="https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2" rel="canonical"/>
#   <link data-rh="true" href="android-app://com.medium.reader/https/medium.com/p/f98d22fac8e2" rel="alternate"/>
#   <script data-rh="true" type="application/ld+json">
#    {"@context":"http:\u002F\u002Fschema.org","@type":"NewsArticle","image":["https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fda:true\u002Fresize:fit:1200\u002F0*24B-GT-dWuxmF_vX"],"url":"https:\u002F\u002Fmedium.com\u002F@aminasaeed223\u002Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2","dateCreated":"2023-10-19T06:52:56.421Z","datePublished":"2023-10-19T06:52:56.421Z","dateModified":"2023-10-19T06:53:05.250Z","headline":"A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code","name":"A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code","description":"In the world of programming and data science, efficient management of software dependencies is crucial. Miniconda, a lightweight distribution of the popular Anaconda Python distribution, provides a…","identifier":"f98d22fac8e2","author":{"@type":"Person","name":"Amina Saeed","url":"https:\u002F\u002Fmedium.com\u002F@aminasaeed223"},"creator":["Amina Saeed"],"publisher":{"@type":"Organization","name":"Medium","url":"https:\u002F\u002Fmedium.com\u002F","logo":{"@type":"ImageObject","width":308,"height":60,"url":"https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fresize:fit:616\u002F1*OMF3fSqH8t4xBJ9-6oZDZw.png"}},"mainEntityOfPage":"https:\u002F\u002Fmedium.com\u002F@aminasaeed223\u002Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2"}
#   </script>
#   <style data-fela-rehydration="507" data-fela-type="STATIC" type="text/css">
#    html{box-sizing:border-box;-webkit-text-size-adjust:100%}*, *:before, *:after{box-sizing:inherit}body{margin:0;padding:0;text-rendering:optimizeLegibility;-webkit-font-smoothing:antialiased;color:rgba(0,0,0,0.8);position:relative;min-height:100vh}h1, h2, h3, h4, h5, h6, dl, dd, ol, ul, menu, figure, blockquote, p, pre, form{margin:0}menu, ol, ul{padding:0;list-style:none;list-style-image:none}main{display:block}a{color:inherit;text-decoration:none}a, button, input{-webkit-tap-highlight-color:transparent}img, svg{vertical-align:middle}button{background:transparent;overflow:visible}button, input, optgroup, select, textarea{margin:0}:root{--reach-tabs:1;--reach-menu-button:1}#speechify-root{font-family:Sohne, sans-serif}div[data-popper-reference-hidden="true"]{visibility:hidden;pointer-events:none}
# /*XCode style (c) Angel Garcia <angelgarcia.mail@gmail.com>*/.hljs {background: #fff;color: black;
# }/* Gray DOCTYPE selectors like WebKit */
# .xml .hljs-meta {color: #c0c0c0;
# }.hljs-comment,
# .hljs-quote {color: #007400;
# }.hljs-tag,
# .hljs-attribute,
# .hljs-keyword,
# .hljs-selector-tag,
# .hljs-literal,
# .hljs-name {color: #aa0d91;
# }.hljs-variable,
# .hljs-template-variable {color: #3F6E74;
# }.hljs-code,
# .hljs-string,
# .hljs-meta .hljs-string {color: #c41a16;
# }.hljs-regexp,
# .hljs-link {color: #0E0EFF;
# }.hljs-title,
# .hljs-symbol,
# .hljs-bullet,
# .hljs-number {color: #1c00cf;
# }.hljs-section,
# .hljs-meta {color: #643820;
# }.hljs-title.class_,
# .hljs-class .hljs-title,
# .hljs-type,
# .hljs-built_in,
# .hljs-params {color: #5c2699;
# }.hljs-attr {color: #836C28;
# }.hljs-subst {color: #000;
# }.hljs-formula {background-color: #eee;font-style: italic;
# }.hljs-addition {background-color: #baeeba;
# }.hljs-deletion {background-color: #ffc8bd;
# }.hljs-selector-id,
# .hljs-selector-class {color: #9b703f;
# }.hljs-doctag,
# .hljs-strong {font-weight: bold;
# }.hljs-emphasis {font-style: italic;
# }
#   </style>
#   <style data-fela-rehydration="507" data-fela-type="KEYFRAME" type="text/css">
#    @-webkit-keyframes k1{0%{opacity:0.8}50%{opacity:0.5}100%{opacity:0.8}}@-moz-keyframes k1{0%{opacity:0.8}50%{opacity:0.5}100%{opacity:0.8}}@keyframes k1{0%{opacity:0.8}50%{opacity:0.5}100%{opacity:0.8}}@-webkit-keyframes k2{0%{transform:scale(1)}50%{transform:scale(1.1)}100%{transform:scale(1)}}@-moz-keyframes k2{0%{transform:scale(1)}50%{transform:scale(1.1)}100%{transform:scale(1)}}@keyframes k2{0%{transform:scale(1)}50%{t

# %%
for link in data.find_all("a"):
    print(link.get("href"))
    
print(data.get_text())
# Out:
# https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Ff98d22fac8e2&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderUser&source=---two_column_layout_nav----------------------------------
# /m/signin?operation=login&redirect=https%3A%2F%2Fmedium.com%2F%40aminasaeed223%2Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2&source=post_page---two_column_layout_nav-----------------------global_nav-----------
# /?source=---two_column_layout_nav----------------------------------
# /m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2Fnew-story&source=---two_column_layout_nav-----------------------new_post_topnav-----------
# /search?source=---two_column_layout_nav----------------------------------
# /m/signin?operation=login&redirect=https%3A%2F%2Fmedium.com%2F%40aminasaeed223%2Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2&source=post_page---two_column_layout_nav-----------------------global_nav-----------
# /@aminasaeed223?source=post_page-----f98d22fac8e2--------------------------------
# /@aminasaeed223?source=post_page-----f98d22fac8e2--------------------------------
# /m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fsubscribe%2Fuser%2Fd04497913581&operation=register&redirect=https%3A%2F%2Fmedium.com%2F%40aminasaeed223%2Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2&user=Amina+Saeed&userId=d04497913581&source=post_page-d04497913581----f98d22fac8e2---------------------post_header-----------
# https://docs.conda.io/en/latest/miniconda.html
# /tag/anaconda?source=post_page-----f98d22fac8e2---------------anaconda-----------------
# /tag/miniconda?source=post_page-----f98d22fac8e2---------------miniconda-----------------
# /tag/data-science?source=post_page-----f98d22fac8e2---------------data_science-----------------
# /@aminasaeed223?source=post_page-----f98d22fac8e2--------------------------------
# /m/signin?actionUrl=%2F_%2Fapi%2Fusers%2Fd04497913581%2Flazily-enable-writer-subscription&operation=register&redirect=https%3A%2F%2Fmedium.com%2F%40aminasaeed223%2Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2&user=Amina+Saeed&userId=d04497913581&source=-----f98d22fac8e2---------------------subscribe_user-----------
# /@aminasaeed223?source=post_page-----f98d22fac8e2--------------------------------
# /@aminasaeed223/followers?source=post_page-----f98d22fac8e2--------------------------------
# /m/signin?actionUrl=%2F_%2Fapi%2Fusers%2Fd04497913581%2Flazily-enable-writer-subscription&operation=register&redirect=https%3A%2F%2Fmedium.com%2F%40aminasaeed223%2Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2&user=Amina+Saeed&userId=d04497913581&source=-----f98d22fac8e2---------------------subscribe_user-----------
# https://help.medium.com/hc/en-us?source=post_page-----f98d22fac8e2--------------------------------
# https://medium.statuspage.io/?source=post_page-----f98d22fac8e2--------------------------------
# /about?autoplay=1&source=post_page-----f98d22fac8e2--------------------------------
# /jobs-at-medium/work-at-medium-959d1a85284e?source=post_page-----f98d22fac8e2--------------------------------
# https://blog.medium.com/?source=post_page-----f98d22fac8e2--------------------------------
# https://policy.medium.com/medium-privacy-policy-f03bf92035c9?source=post_page-----f98d22fac8e2--------------------------------
# https://policy.medium.com/medium-terms-of-service-9db0094a1e0f?source=post_page-----f98d22fac8e2--------------------------------
# https://speechify.com/medium?source=post_page-----f98d22fac8e2--------------------------------
# /business?source=post_page-----f98d22fac8e2--------------------------------
# A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code | by Amina Saeed | MediumOpen in appSign upSign inWriteSign upSign inA Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS CodeAmina Saeed·Follow4 min read·Oct 19, 2023--ListenShareIn the world of programming and data science, efficient management of software dependencies is crucial.Miniconda, a lightweight distribution of the popular Anaconda Python distribution, provides a powerful solution for managing package dependencies and creating isolated virtual environments.In this tutorial, we will explore what Miniconda is, the concept of virtual environments, and how to set them up using Miniconda in conjunction with the popular code editor, Visual Studio Code (VS Code).What is Miniconda?Miniconda is a minimal version of the Anaconda Python distribution, which includes only the necessary components required to run Python and manage packages.It provides a lightweight, command-line tool that simplifies the installation and management of software dependencies, making it an excellent choice for developers who prefer a more streamlined approach.Understanding Virtual Environments:Virtual environments are isolated environments that allow you to have separate installations of Python and packages for different projects. They enable you to avoid conflicts between different versions of packages and ensure project reproducibility.By creating a virtual environment, you can have a self-contained workspace with its own Python interpreter and package dependencies. This means that any changes made within the virtual environment will not affect the global Python installation or other virtual environments.Installing Miniconda:To get started with Miniconda, you’ll first need to download and install it on your system. Follow these steps:Step 1: Visit the Miniconda website (https://docs.conda.io/en/latest/miniconda.html).Step 2: Choose the appropriate installer for your operating system (Windows, macOS, or Linux).Step 3: Download the installer and run it.Step 4: Follow the on-screen instructions to complete the installation.Once the installation is complete, you can open a terminal or command prompt to verify that Miniconda has been installed correctly by running the following command:conda --versionIf the command displays the version of Conda, you have successfully installed Miniconda.Creating a New Virtual Environment:To create a new virtual environment, follow these steps:Step 1: Open a terminal or command prompt.Step 2: Run the following command to create a new virtual environment:conda create --name myenvReplace myenv with the desired name for your virtual environment. Conda will create a new environment with the specified name and install a minimal set of packages.Activating and Deactivating Virtual Environments:Once you have created a virtual environment, you need to activate it to start using it. Follow these steps:Step 1: Open a terminal or command prompt.Step 2: Activate the environment using the following command:For Windows:conda activate myenvFor macOS and Linux:source activate myenvThe name myenv should match the name of the environment you created in the previous step.To deactivate the virtual environment and return to the global Python environment, use the following command:For Windows:conda deactivateFor macOS and Linux:source deactivateInstalling Packages in the Virtual Environment:With the virtual environment activated, you can now install Python packages specific to your project. Use the conda install or pip install command to install packages, just like you would in a regular Python environment. For example:conda install numpypip install pandasSetting Up Miniconda with VS Code:Visual Studio Code (VS Code) is a popular code editor that provides excellent support for Python development. To integrate Miniconda with VS Code, follow these steps:Step 1: Install the “Python” extension within VS Code. This ...

# %%
print(data.prettify()[0:10000])

for link in data.find_all("a",attrs={"href":re.compile("^http")}):
    print(link)
    
type(link)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title data-rh="true">
#    A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code | by Amina Saeed | Medium
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1" data-rh="true" name="viewport"/>
#   <meta content="#000000" data-rh="true" name="theme-color"/>
#   <meta content="Medium" data-rh="true" name="twitter:app:name:iphone"/>
#   <meta content="828256236" data-rh="true" name="twitter:app:id:iphone"/>
#   <meta content="Medium" data-rh="true" property="al:ios:app_name"/>
#   <meta content="828256236" data-rh="true" property="al:ios:app_store_id"/>
#   <meta content="com.medium.reader" data-rh="true" property="al:android:package"/>
#   <meta content="542599432471018" data-rh="true" property="fb:app_id"/>
#   <meta content="Medium" data-rh="true" property="og:site_name"/>
#   <meta content="article" data-rh="true" property="og:type"/>
#   <meta content="2023-10-19T06:52:56.421Z" data-rh="true" property="article:published_time"/>
#   <meta content="A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code | by Amina Saeed | Medium" data-rh="true" name="title"/>
#   <meta content="A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code" data-rh="true" property="og:title"/>
#   <meta content="medium://p/f98d22fac8e2" data-rh="true" property="al:android:url"/>
#   <meta content="medium://p/f98d22fac8e2" data-rh="true" property="al:ios:url"/>
#   <meta content="Medium" data-rh="true" property="al:android:app_name"/>
#   <meta content="In the world of programming and data science, efficient management of software dependencies is crucial. Miniconda, a lightweight distribution of the popular Anaconda Python distribution, provides a…" data-rh="true" name="description"/>
#   <meta content="In the world of programming and data science, efficient management of software dependencies is crucial." data-rh="true" property="og:description"/>
#   <meta content="https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2" data-rh="true" property="og:url"/>
#   <meta content="https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2" data-rh="true" property="al:web:url"/>
#   <meta content="https://miro.medium.com/v2/da:true/resize:fit:1200/0*24B-GT-dWuxmF_vX" data-rh="true" property="og:image"/>
#   <meta content="https://medium.com/@aminasaeed223" data-rh="true" property="article:author"/>
#   <meta content="Amina Saeed" data-rh="true" name="author"/>
#   <meta content="index,follow,max-image-preview:large" data-rh="true" name="robots"/>
#   <meta content="unsafe-url" data-rh="true" name="referrer"/>
#   <meta content="A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code" data-rh="true" property="twitter:title"/>
#   <meta content="@Medium" data-rh="true" name="twitter:site"/>
#   <meta content="medium://p/f98d22fac8e2" data-rh="true" name="twitter:app:url:iphone"/>
#   <meta content="In the world of programming and data science, efficient management of software dependencies is crucial." data-rh="true" property="twitter:description"/>
#   <meta content="https://miro.medium.com/v2/da:true/resize:fit:1200/0*24B-GT-dWuxmF_vX" data-rh="true" name="twitter:image:src"/>
#   <meta content="summary_large_image" data-rh="true" name="twitter:card"/>
#   <meta content="Reading time" data-rh="true" name="twitter:label1"/>
#   <meta content="4 min read" data-rh="true" name="twitter:data1"/>
#   <meta content="2" data-rh="true" name="twitter:tile:template:testing"/>
#   <meta content="https://miro.medium.com/v2/da:true/resize:fit:1200/0*24B-GT-dWuxmF_vX" data-rh="true" name="twitter:tile:image"/>
#   <meta content="Person" data-rh="true" name="twitter:tile:info1:icon"/>
#   <meta content="Amina Saeed" data-rh="true" name="twitter:tile:info1:text"/>
#   <meta content="Calendar" data-rh="true" name="twitter:tile:info2:icon"/>
#   <meta content="Oct 19, 2023" data-rh="true" name="twitter:tile:info2:text"/>
#   <meta content="Read on Medium" data-rh="true" name="twitter:cta"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/1*m-R_BkNf1Qjr1YbyOIJY2w.png" rel="icon"/>
#   <link data-rh="true" href="/osd.xml" rel="search" title="Medium" type="application/opensearchdescription+xml"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:152:152/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:120:120/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:76:76/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link data-rh="true" href="https://miro.medium.com/v2/resize:fill:60:60/1*sHhtYhaCe2Uc3IU0IgKwIQ.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link color="#171717" data-rh="true" href="https://cdn-static-1.medium.com/_/fp/icons/Medium-Avatar-500x500.svg" rel="mask-icon"/>
#   <link crossorigin="" data-rh="true" href="https://glyph.medium.com" rel="preconnect"/>
#   <link as="style" data-rh="true" href="https://glyph.medium.com/css/unbound.css" id="glyph_preload_link" rel="preload" type="text/css"/>
#   <link data-rh="true" href="https://glyph.medium.com/css/unbound.css" id="glyph_link" rel="stylesheet" type="text/css"/>
#   <link data-rh="true" href="https://medium.com/@aminasaeed223" rel="author"/>
#   <link data-rh="true" href="https://medium.com/@aminasaeed223/a-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2" rel="canonical"/>
#   <link data-rh="true" href="android-app://com.medium.reader/https/medium.com/p/f98d22fac8e2" rel="alternate"/>
#   <script data-rh="true" type="application/ld+json">
#    {"@context":"http:\u002F\u002Fschema.org","@type":"NewsArticle","image":["https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fda:true\u002Fresize:fit:1200\u002F0*24B-GT-dWuxmF_vX"],"url":"https:\u002F\u002Fmedium.com\u002F@aminasaeed223\u002Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2","dateCreated":"2023-10-19T06:52:56.421Z","datePublished":"2023-10-19T06:52:56.421Z","dateModified":"2023-10-19T06:53:05.250Z","headline":"A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code","name":"A Comprehensive Tutorial on Miniconda: Creating Virtual Environments and Setting Up with VS Code","description":"In the world of programming and data science, efficient management of software dependencies is crucial. Miniconda, a lightweight distribution of the popular Anaconda Python distribution, provides a…","identifier":"f98d22fac8e2","author":{"@type":"Person","name":"Amina Saeed","url":"https:\u002F\u002Fmedium.com\u002F@aminasaeed223"},"creator":["Amina Saeed"],"publisher":{"@type":"Organization","name":"Medium","url":"https:\u002F\u002Fmedium.com\u002F","logo":{"@type":"ImageObject","width":308,"height":60,"url":"https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fresize:fit:616\u002F1*OMF3fSqH8t4xBJ9-6oZDZw.png"}},"mainEntityOfPage":"https:\u002F\u002Fmedium.com\u002F@aminasaeed223\u002Fa-comprehensive-tutorial-on-miniconda-creating-virtual-environments-and-setting-up-with-vs-code-f98d22fac8e2"}
#   </script>
#   <style data-fela-rehydration="507" data-fela-type="STATIC" type="text/css">
#    html{box-sizing:border-box;-webkit-text-size-adjust:100%}*, *:before, *:after{box-sizing:inherit}body{margin:0;padding:0;text-rendering:optimizeLegibility;-webkit-font-smoothing:antialiased;color:rgba(0,0,0,0.8);position:relative;min-height:100vh}h1, h2, h3, h4, h5, h6, dl, dd, ol, ul, menu, figure, blockquote, p, pre, form{margin:0}menu, ol, ul{padding:0;list-style:none;list-style-image:none}main{display:block}a{color:inherit;text-decoration:none}a, button, input{-webkit-tap-highlight-color:transparent}img, svg{vertical-align:middle}button{background:transparent;overflow:visible}button, input, optgroup, select, textarea{margin:0}:root{--reach-tabs:1;--reach-menu-button:1}#speechify-root{font-family:Sohne, sans-serif}div[data-popper-reference-hidden="true"]{visibility:hidden;pointer-events:none}
# /*XCode style (c) Angel Garcia <angelgarcia.mail@gmail.com>*/.hljs {background: #fff;color: black;
# }/* Gray DOCTYPE selectors like WebKit */
# .xml .hljs-meta {color: #c0c0c0;
# }.hljs-comment,
# .hljs-quote {color: #007400;
# }.hljs-tag,
# .hljs-attribute,
# .hljs-keyword,
# .hljs-selector-tag,
# .hljs-literal,
# .hljs-name {color: #aa0d91;
# }.hljs-variable,
# .hljs-template-variable {color: #3F6E74;
# }.hljs-code,
# .hljs-string,
# .hljs-meta .hljs-string {color: #c41a16;
# }.hljs-regexp,
# .hljs-link {color: #0E0EFF;
# }.hljs-title,
# .hljs-symbol,
# .hljs-bullet,
# .hljs-number {color: #1c00cf;
# }.hljs-section,
# .hljs-meta {color: #643820;
# }.hljs-title.class_,
# .hljs-class .hljs-title,
# .hljs-type,
# .hljs-built_in,
# .hljs-params {color: #5c2699;
# }.hljs-attr {color: #836C28;
# }.hljs-subst {color: #000;
# }.hljs-formula {background-color: #eee;font-style: italic;
# }.hljs-addition {background-color: #baeeba;
# }.hljs-deletion {background-color: #ffc8bd;
# }.hljs-selector-id,
# .hljs-selector-class {color: #9b703f;
# }.hljs-doctag,
# .hljs-strong {font-weight: bold;
# }.hljs-emphasis {font-style: italic;
# }
#   </style>
#   <style data-fela-rehydration="507" data-fela-type="KEYFRAME" type="text/css">
#    @-webkit-keyframes k1{0%{opacity:0.8}50%{opacity:0.5}100%{opacity:0.8}}@-moz-keyframes k1{0%{opacity:0.8}50%{opacity:0.5}100%{opacity:0.8}}@keyframes k1{0%{opacity:0.8}50%{opacity:0.5}100%{opacity:0.8}}@-webkit-keyframes k2{0%{transform:scale(1)}50%{transform:scale(1.1)}100%{transform:scale(1)}}@-moz-keyframes k2{0%{transform:scale(1)}50%{transform:scale(1.1)}100%{transform:scale(1)}}@keyframes k2{0%{transform:scale(1)}50%{t
# <a class="dt ag du be ak b am an ao ap aq ar as at s u w i d q dv z" href="https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Ff98d22fac8e2&amp;%7Efeature=LoOpenInAppButton&amp;%7Echannel=ShowPostUnderUser&amp;source=---two_column_layout_nav----------------------------------" rel="noopener follow">Open in app<svg class="ds" fill="none" height="10" viewbox="0 0 10 10" width="10"><path d="M.98 8.48a.37.37 0 1 0 .54.54l-.54-.54zm7.77-7.23h.38c0-.2-.17-.38-.38-.38v.38zM8.37 6.5a.37.37 0 1 0 .76 0h-.76zM3.5.87a.37.37 0 1 0 0 .76V.88zM1.52 9.03l7.5-7.5-.54-.54-7.5 7.5.54.54zm6.86-7.77V6.5h.74V1.25h-.74zm-4.88.38h5.25V.88H3.5v.74z" fill="currentColor"></path></svg></a>
# <a class="af pl" href="https://docs.conda.io/en/latest/miniconda.html" rel="noopener ugc nofollow" target="_blank">https://docs.conda.io/en/latest/miniconda.html</a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://help.medium.com/hc/en-us?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Help</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://medium.statuspage.io/?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Status</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://blog.medium.com/?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Blog</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://policy.medium.com/medium-privacy-policy-f03bf92035c9?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Privacy</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://policy.medium.com/medium-terms-of-service-9db0094a1e0f?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Terms</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://speechify.com/medium?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Text to speech</p></a>
# bs4.element.Tag

# %%
file = open("parsed_data.txt","w")
for link in data.find_all("a",attrs={"href":re.compile("^http")}):
    data_link=str(link)
    print(data_link)
    file.write(data_link)
    
file.flush()
file.close()
# Out:
# <a class="dt ag du be ak b am an ao ap aq ar as at s u w i d q dv z" href="https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Ff98d22fac8e2&amp;%7Efeature=LoOpenInAppButton&amp;%7Echannel=ShowPostUnderUser&amp;source=---two_column_layout_nav----------------------------------" rel="noopener follow">Open in app<svg class="ds" fill="none" height="10" viewbox="0 0 10 10" width="10"><path d="M.98 8.48a.37.37 0 1 0 .54.54l-.54-.54zm7.77-7.23h.38c0-.2-.17-.38-.38-.38v.38zM8.37 6.5a.37.37 0 1 0 .76 0h-.76zM3.5.87a.37.37 0 1 0 0 .76V.88zM1.52 9.03l7.5-7.5-.54-.54-7.5 7.5.54.54zm6.86-7.77V6.5h.74V1.25h-.74zm-4.88.38h5.25V.88H3.5v.74z" fill="currentColor"></path></svg></a>
# <a class="af pl" href="https://docs.conda.io/en/latest/miniconda.html" rel="noopener ugc nofollow" target="_blank">https://docs.conda.io/en/latest/miniconda.html</a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://help.medium.com/hc/en-us?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Help</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://medium.statuspage.io/?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Status</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://blog.medium.com/?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Blog</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://policy.medium.com/medium-privacy-policy-f03bf92035c9?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Privacy</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://policy.medium.com/medium-terms-of-service-9db0094a1e0f?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Terms</p></a>
# <a class="af ag ah ai aj ak al am an ao ap aq ar as at" href="https://speechify.com/medium?source=post_page-----f98d22fac8e2--------------------------------" rel="noopener follow"><p class="be b du z dt">Text to speech</p></a>
